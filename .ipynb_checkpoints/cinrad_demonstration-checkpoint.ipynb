# %%
"""
Anconda (Python 3.7) configuration
- install anaconda 3.7 on your system
- open terminal with anaconda active
- create new python environment for cinrad 'conda create -n myenv python=3.7'
- activate the cinrad environment (this will need to be done everytime you reopen the terminal or change environment)
- install cartopy and numpy ' conda install -c conda-forge cartopy numpy'
- install cinrad fork of PyART (PyART is a set of libraries for reading, correcting and plotting radar data)
    - first clone(download) the source code to a local direction - git clone https://github.com/zxdawn/pyart
    - move to folder of cinrad library and install source code - python setup.py install
    
Now the libraris are installed
to run the code either use
- use your new cinrad environment from pycharm - https://medium.com/infinity-aka-aseem/how-to-setup-pycharm-with-an-anaconda-virtual-environment-already-created-fb927bacbe61
- use the jupyter notebooks edittor that is included in anaconda - type into active terminal 'jupyter notebook'

# example from Nanjing - https://github.com/zxdawn/pyart/blob/CNRAD/notebooks/Reading_S_band_radar_en.ipynb
Done!
"""


#system libraries
import glob
import os

#central libraries
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs # A toolkit for map projections
import cartopy.io.img_tiles as img_tiles 


#pyart libraries
import pyart
from pyart.io.sband_archive import read_sband_archive

# %%
"""
TODO

- vertical cross section secondary plot - https://arm-doe.github.io/pyart/dev/auto_examples/plotting/plot_three_panel_gridmapdisplay.html
- better map background
- increase font size of marker
- create automated site lat/lon finder


"""
# Out:
# '\nTODO\n\n- vertical cross section secondary plot - https://arm-doe.github.io/pyart/dev/auto_examples/plotting/plot_three_panel_gridmapdisplay.html\n- better map background\n- increase font size of marker\n- create automated site lat/lon finder\n\n\n'

# %%
#configuration block

#path to data
source_path = '/home/meso/dev/luzhou_radar_20190424/cinrad_data' #these are *.bin files
image_path  = '/home/meso/dev/luzhou_radar_20190424/images'

#location and altitude of radar (not in bin files currently)
radar_lat   = 29.5219
radar_lon   = 106.4889
radar_alt   = 438.8
#full list of CMA radar stations here: https://github.com/expertyang/read_cinrad/blob/master/radar_info.txt

#list of sweep indicies which contain reflectivity (note that sweeps 1 and 3 only contain radial velocity)
valid_sweep_list = [0,2,4,5,6,7,8,9,10]
#name of reflectivity field
plot_field  = 'reflectivity'
#sweep index for plotting
plot_sweep  = 2

# colormap types and ranges
if plot_field == 'reflectivity':
    vmin = -8
    vmax = 64
    cmap = pyart.graph.cm.NWSRef
if plot_field == 'velocity':
    vmin = -15
    vmax = 15
    cmap = pyart.graph.cm.BuDRd18  

#setup map extend and lat/lon lines
map_range  = 1.6 #degrees
line_space = 0.2 #degrees
min_lat    = radar_lat - map_range
max_lat    = radar_lat + map_range
min_lon    = radar_lon - map_range
max_lon    = radar_lon + map_range
lat_lines  = np.arange(min_lat, max_lat+line_space, line_space)
lon_lines  = np.arange(min_lon, max_lon+line_space, line_space)

# Set up the GIS projection
projection = ccrs.Mercator(
                central_longitude=radar_lon,
                min_latitude=min_lat, max_latitude=max_lat)

#mapping tiles (make it pretty)
#these credientials are from my personal account - alternatively openstreetmaps can be used.
mapbox_token = 'k.eyJ1IjoianNzNDMyIiwiYSI6ImNqbXZpYnB6djA1YWozcG13azNtOGx4cjgifQ.ti9LEeP0RI-e7tf2mohr-A'
mapbox_un    = 'jss432'
mapbox_un    = 'cjmvijl100fmg2slyy4ft79dn'
    
#read file list from data directory
data_ffn_list = sorted(glob.glob(source_path + '/*.bin'))

# %%
def plot_data(data_ffn, output_filename):
    
    #read data
    radar = read_sband_archive(data_ffn, station=(radar_lat, radar_lon, radar_alt))
    #extract sweeps which have reflectivity
    radar = radar.extract_sweeps(valid_sweep_list)
    
    #create pyart display object for plotting
    display = pyart.graph.RadarMapDisplayCartopy(radar)

    #generate request for mapping tiles
    #https://scitools.org.uk/cartopy/docs/latest/_modules/cartopy/io/img_tiles.html
    request = img_tiles.MapboxStyleTiles(mapbox_token, mapbox_un, mapbox_un)
    
    #plot PPI
    display.plot_ppi_map(plot_field, plot_sweep,
                            projection=projection, resolution='10m',
                            vmin=vmin, vmax=vmax, 
                            max_lat = max_lat, min_lat = min_lat, min_lon = min_lon, max_lon = max_lon,
                            cmap = cmap)
    
    #add mapping tiles
    ax = plt.gca()
    ax.add_image(request, 8)
    
    #add grid lines and set style
    gl = display.ax.gridlines(draw_labels=True,
                                  linewidth=2, color='gray', alpha=0.5,
                                  linestyle='--')
    #set plot x and y label styles and visibility
    gl.xlabel_style = {'size': 20}
    gl.ylabel_style = {'size': 20}
    gl.xlabels_top = False
    gl.ylabels_right = False
    
    ###########################################################
    #add marker for luzhou
    luzhou_lat = 28.871
    luzhou_lon = 105.442
    display.plot_point(luzhou_lon, luzhou_lat,
               label_text = 'Luzhou', 
               label_offset=[.02,.02], symbol = 'bo' )
    ###########################################################
    
    #save figure
    if output_filename is not None:
        plt.savefig(output_filename)
        plt.close()

# %%
##Example 1: Plot a single data file

#create figure
fig = plt.figure(figsize=[15, 15], facecolor='w')

#select one data file to plot
test_data_ffn = data_ffn_list[0]
#plot data file
plot_data(test_data_ffn, None)
# Out:
# /home/meso/anaconda3/lib/python3.6/site-packages/pyart/io/sband_archive.py:183: UserWarning: Gate spacing is not constant, interpolating data in scans [0, 2, 4, 5, 6, 7, 8, 9, 10] for moment REF.
#   UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-edb9c3ebbf95> in <module>()
#       7 test_data_ffn = data_ffn_list[0]
#       8 #plot data file
# ----> 9 plot_data(test_data_ffn, None)
#
# <ipython-input-28-4f3edfa54f6b> in plot_data(data_ffn, output_filename)
#      10
#      11     #generate request for mapping tiles
# ---> 12     request = img_tiles.MapboxStyleTiles(mapbox_token, mapbox_un, mapbox_un)
#      13
#      14     #plot PPI
#
# AttributeError: module 'cartopy.io.img_tiles' has no attribute 'MapboxStyleTiles'

# %%
#Example 2: Save plot images for all data files in the source folder

#create figure
fig = plt.figure(figsize=[15, 15], facecolor='w')

for data_ffn in data_ffn_list:
    #create image fn for output
    data_fn = os.path.basename(data_ffn)
    image_fn = image_path + '/' + data_fn[15:27] + '.png'
    #plot and save
    plot_data(data_ffn, image_fn)
    #clear figure
    plt.clear()
# Out:
# /home/meso/anaconda3/lib/python3.6/site-packages/pyart/io/sband_archive.py:183: UserWarning: Gate spacing is not constant, interpolating data in scans [0, 2, 4, 5, 6, 7, 8, 9, 10] for moment REF.
#   UserWarning)
